# %%
import pandas as pd

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'],
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
#creating^

# %%
pwd
# Out:
# '/'

# %%
wine_reviews = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/dqthon-participants.csv")

# %%
wine_reviews.shape
# Out:
# (5000, 10)

# %%
wine_reviews.head()
# Out:
#                          participant_id first_name   last_name   birth_date  \
# 0  bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a      Citra  Nurdiyanti  05 Feb 1991
# 1  7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3       Aris    Setiawan  11 Jan 1993
# 2  19582d7f-b824-4fe5-a517-d5bf573fc768   Cornelia   Handayani  31 Jul 1993
# 3  aeb6d817-25f3-4867-8a74-8d92e0a0f633      Soleh      Rajasa  04 Nov 1991
# 4  1fdabdd9-5444-4c97-87b2-fe8833ad0d27       Vivi      Astuti  22 Jan 2003
#
#                                              address        phone_number  \
# 0           Gg. Monginsidi No. 08\nMedan, Aceh 80734     (0151) 081 2706
# 1     Gg. Rajawali Timur No. 7\nPrabumulih, MA 09434  +62 (036) 461 7027
# 2             Jalan Kebonjati No. 0\nAmbon, SS 57739        089 833 6695
# 3    Jl. Yos Sudarso No. 109\nLubuklinggau, SR 76156  +62 (418) 329-4756
# 4  Jalan Gardujati No. 53\nKediri, Sulawesi Tenga...          0812511835
#
# ...

# %%
wine_reviews = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/dqthon-participants.csv", index_col=0)
wine_reviews.head()
# Out:
#                                      first_name   last_name   birth_date  \
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a      Citra  Nurdiyanti  05 Feb 1991
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3       Aris    Setiawan  11 Jan 1993
# 19582d7f-b824-4fe5-a517-d5bf573fc768   Cornelia   Handayani  31 Jul 1993
# aeb6d817-25f3-4867-8a74-8d92e0a0f633      Soleh      Rajasa  04 Nov 1991
# 1fdabdd9-5444-4c97-87b2-fe8833ad0d27       Vivi      Astuti  22 Jan 2003
#
#                                                                                 address  \
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a           Gg. Monginsidi No. 08\nMedan, Aceh 80734
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3     Gg. Rajawali Timur No. 7\nPrabumulih, MA 09434
# 19582d7f-b824-4fe5-a517-d5bf573fc768             Jalan Kebonjati No. 0\nAmbon, SS 57739
# aeb6d817-25f3-4867-8a74-8d92e0a0f633    Jl. Yos Sudarso No. 109\nLubuklinggau, SR 76156
# ...

# %%
wine_reviews.country
# Out:
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a        Georgia
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3    Korea Utara
# 19582d7f-b824-4fe5-a517-d5bf573fc768         Komoro
# aeb6d817-25f3-4867-8a74-8d92e0a0f633        Eritrea
# 1fdabdd9-5444-4c97-87b2-fe8833ad0d27       Aljazair
#                                            ...
# 5f084245-58cb-4360-8cff-112f06f7214e       Hongaria
# fc6e142a-3f66-4330-9975-8c1dc7f9bb03       Norwegia
# 4521ff9f-4aec-401b-84aa-a4e6fc6549a4          Ghana
# 1c91596e-427c-44a7-b7d0-974f44e18381         Gambia
# 5d682e84-bcb5-43e9-8ce0-615364f5376a      Singapura
# Name: country, Length: 5000, dtype: object

# %%
wine_reviews['country']
# Out:
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a        Georgia
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3    Korea Utara
# 19582d7f-b824-4fe5-a517-d5bf573fc768         Komoro
# aeb6d817-25f3-4867-8a74-8d92e0a0f633        Eritrea
# 1fdabdd9-5444-4c97-87b2-fe8833ad0d27       Aljazair
#                                            ...
# 5f084245-58cb-4360-8cff-112f06f7214e       Hongaria
# fc6e142a-3f66-4330-9975-8c1dc7f9bb03       Norwegia
# 4521ff9f-4aec-401b-84aa-a4e6fc6549a4          Ghana
# 1c91596e-427c-44a7-b7d0-974f44e18381         Gambia
# 5d682e84-bcb5-43e9-8ce0-615364f5376a      Singapura
# Name: country, Length: 5000, dtype: object

# %%
wine_reviews['country'][13: 32]
# Out:
# participant_id
# 511d94e6-ee70-4afe-8516-4df0d7f74698       Uzbekistan
# 5bb00c77-c91d-47bc-9dbc-996efcd5b76e         Botswana
# b11b5a7b-654f-4a6a-84be-6c9bfc116c94           Gambia
# 8f5cc17e-71b5-47a4-b70e-fae7d7a0c46f             Iran
# 407116ef-fb38-432f-b62e-d955d9ca1712    Sudan Selatan
# 17dd1666-818e-4681-bedd-b9f016096c74        Indonesia
# 88bede2b-2d5a-45c6-8ade-c1a3289f2728          Georgia
# 3810d4c7-9c7f-4f46-95e6-dd81ff5f9356        Venezuela
# 540a4551-222c-4508-be21-919bc920f667        Argentina
# 37f4aed3-5e39-4620-ac1e-6b82f3ea1a8e           Brunei
# 1abb5ace-e2f8-4ac3-90d5-cdd70838ca50         Norwegia
# 80c5fc2b-c315-42d0-9a6f-101314baff32         Islandia
# 83d9dbf8-f13d-4171-989a-8995ec10468e            Ghana
# f8d019ac-5beb-4855-be29-ecc5c39d4d7f          Rumania
# f26e2057-3968-423f-a948-575e577f8c0d           Malawi
# c96ad235-14db-41ec-ad57-11e8898df1da            Haiti
# 0effee30-7b9a-42b4-bc99-0bd9b10324b2       Kosta Rika
# ...

# %%
wine_reviews.iloc[0]
# Out:
# first_name                                          Citra
# last_name                                      Nurdiyanti
# birth_date                                    05 Feb 1991
# address          Gg. Monginsidi No. 08\nMedan, Aceh 80734
# phone_number                              (0151) 081 2706
# country                                           Georgia
# institute                            UD Prakasa Mandasari
# occupation                 Business Intelligence Engineer
# register_time                                1617634046.0
# Name: bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a, dtype: object

# %%
wine_reviews.iloc[:, 0]
# Out:
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a       Citra
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3        Aris
# 19582d7f-b824-4fe5-a517-d5bf573fc768    Cornelia
# aeb6d817-25f3-4867-8a74-8d92e0a0f633       Soleh
# 1fdabdd9-5444-4c97-87b2-fe8833ad0d27        Vivi
#                                           ...
# 5f084245-58cb-4360-8cff-112f06f7214e       Mitra
# fc6e142a-3f66-4330-9975-8c1dc7f9bb03       Indah
# 4521ff9f-4aec-401b-84aa-a4e6fc6549a4       Irsad
# 1c91596e-427c-44a7-b7d0-974f44e18381       Carla
# 5d682e84-bcb5-43e9-8ce0-615364f5376a     Darmana
# Name: first_name, Length: 5000, dtype: object

# %%
wine_reviews.iloc[:3, 0]
# Out:
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a       Citra
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3        Aris
# 19582d7f-b824-4fe5-a517-d5bf573fc768    Cornelia
# Name: first_name, dtype: object

# %%
wine_reviews.iloc[1:3, 0]
# Out:
# participant_id
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3        Aris
# 19582d7f-b824-4fe5-a517-d5bf573fc768    Cornelia
# Name: first_name, dtype: object

# %%
wine_reviews.iloc[[0, 1, 2], 0]
# Out:
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a       Citra
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3        Aris
# 19582d7f-b824-4fe5-a517-d5bf573fc768    Cornelia
# Name: first_name, dtype: object

# %%
wine_reviews.iloc[-5:]
# Out:
#                                      first_name  last_name   birth_date  \
# participant_id
# 5f084245-58cb-4360-8cff-112f06f7214e      Mitra   Latupono  27 Apr 2000
# fc6e142a-3f66-4330-9975-8c1dc7f9bb03      Indah  Rahmawati  06 Mar 1996
# 4521ff9f-4aec-401b-84aa-a4e6fc6549a4      Irsad   Najmudin  14 Feb 2003
# 1c91596e-427c-44a7-b7d0-974f44e18381      Carla   Nasyidah  22 Aug 1994
# 5d682e84-bcb5-43e9-8ce0-615364f5376a    Darmana    Maryadi  09 Feb 2002
#
#                                                                                 address  \
# participant_id
# 5f084245-58cb-4360-8cff-112f06f7214e            Jl. Monginsidi No. 5\nCirebon, BB 50268
# fc6e142a-3f66-4330-9975-8c1dc7f9bb03              Gang Joyoboyo No. 73\nBogor, BT 57434
# 4521ff9f-4aec-401b-84aa-a4e6fc6549a4   Jalan PHH. Mustofa No. 0\nTanjungbalai, MU 95312
# 1c91596e-427c-44a7-b7d0-974f44e18381  Jl. H.J Maemunah No. 955\nManado, Kepulauan Ba...
# ...

# %%
wine_reviews.loc[:, ['occupation', 'birth_date', 'register_time']]
# Out:
#                                                           occupation  \
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a  Business Intelligence Engineer
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3               Frontend Engineer
# 19582d7f-b824-4fe5-a517-d5bf573fc768                Business Analyst
# aeb6d817-25f3-4867-8a74-8d92e0a0f633                 DevOps Engineer
# 1fdabdd9-5444-4c97-87b2-fe8833ad0d27                    Data Analyst
# ...                                                              ...
# 5f084245-58cb-4360-8cff-112f06f7214e  Business Intelligence Engineer
# fc6e142a-3f66-4330-9975-8c1dc7f9bb03                   Data Engineer
# 4521ff9f-4aec-401b-84aa-a4e6fc6549a4              Fullstack Engineer
# 1c91596e-427c-44a7-b7d0-974f44e18381              Fullstack Engineer
# 5d682e84-bcb5-43e9-8ce0-615364f5376a                 DevOps Engineer
#
#                                        birth_date  register_time
# participant_id
# ...

# %%
wine_reviews.set_index("occupation")
# Out:
#                                first_name   last_name   birth_date  \
# occupation
# Business Intelligence Engineer      Citra  Nurdiyanti  05 Feb 1991
# Frontend Engineer                    Aris    Setiawan  11 Jan 1993
# Business Analyst                 Cornelia   Handayani  31 Jul 1993
# DevOps Engineer                     Soleh      Rajasa  04 Nov 1991
# Data Analyst                         Vivi      Astuti  22 Jan 2003
# ...                                   ...         ...          ...
# Business Intelligence Engineer      Mitra    Latupono  27 Apr 2000
# Data Engineer                       Indah   Rahmawati  06 Mar 1996
# Fullstack Engineer                  Irsad    Najmudin  14 Feb 2003
# Fullstack Engineer                  Carla    Nasyidah  22 Aug 1994
# DevOps Engineer                   Darmana     Maryadi  09 Feb 2002
#
#                                                                           address  \
# occupation
# ...

# %%
wine_reviews.country == 'Italy'
# Out:
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a    False
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3    False
# 19582d7f-b824-4fe5-a517-d5bf573fc768    False
# aeb6d817-25f3-4867-8a74-8d92e0a0f633    False
# 1fdabdd9-5444-4c97-87b2-fe8833ad0d27    False
#                                         ...
# 5f084245-58cb-4360-8cff-112f06f7214e    False
# fc6e142a-3f66-4330-9975-8c1dc7f9bb03    False
# 4521ff9f-4aec-401b-84aa-a4e6fc6549a4    False
# 1c91596e-427c-44a7-b7d0-974f44e18381    False
# 5d682e84-bcb5-43e9-8ce0-615364f5376a    False
# Name: country, Length: 5000, dtype: bool

# %%
wine_reviews.country == 'Ghana'
# Out:
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a    False
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3    False
# 19582d7f-b824-4fe5-a517-d5bf573fc768    False
# aeb6d817-25f3-4867-8a74-8d92e0a0f633    False
# 1fdabdd9-5444-4c97-87b2-fe8833ad0d27    False
#                                         ...
# 5f084245-58cb-4360-8cff-112f06f7214e    False
# fc6e142a-3f66-4330-9975-8c1dc7f9bb03    False
# 4521ff9f-4aec-401b-84aa-a4e6fc6549a4     True
# 1c91596e-427c-44a7-b7d0-974f44e18381    False
# 5d682e84-bcb5-43e9-8ce0-615364f5376a    False
# Name: country, Length: 5000, dtype: bool

# %%
wine_reviews.loc[wine_reviews.country == 'Singapura']
# Out:
#                                      first_name    last_name   birth_date  \
# participant_id
# cf7a5801-5fcf-44f0-9a8d-92128061bc24      Wulan       Astuti  31 Aug 1990
# a4c9c009-355c-4bf0-ab51-f02d36fb0483      Reksa        Hakim  09 Nov 1992
# d8131524-bb15-4177-a499-dd5276ec1ebb       Lili      Nasyiah  19 May 2000
# f7d80c18-1c0d-4dd7-b40a-d7277d3ba27c  Anastasia     Yuliarti  01 Aug 1995
# fd06ca1e-4c47-4710-bb91-c05d510cf5d4   Pangestu   Nainggolan  01 Sep 1994
# c8af745a-c498-49cd-ba6d-814465ef8565      Titin  Pudjiastuti  13 Nov 1992
# a90117c8-865e-4428-aa8d-a421ea33dfda      Praba     Ardianto  25 Sep 2000
# 2999f468-a7b8-43cf-b08f-140a27dcdc71     Elvina     Yulianti  08 Mar 1996
# a049220e-5cf0-460c-bfd4-affcf9b5b7aa      Laila      Mulyani  24 Sep 2000
# b5b9e9e7-9681-47e8-8f9b-abb531173834    Ophelia      Susanti  09 May 1997
# b73a9f00-f7ac-4683-9a83-20c31a77a49a      Yahya     Ardianto  10 Sep 2002
# ...

# %%
wine_reviews.loc[wine_reviews.country == 'Korea Utara' & ('wine_reviews.birth_date >= 18 Aug 2000')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-8309eb4cee2e> in <cell line: 1>()
# ----> 1 wine_reviews.loc[wine_reviews.country == 'Korea Utara' & ('wine_reviews.birth_date >= 18 Aug 2000')]
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'

# %%
wine_reviews.loc[(wine_reviews.country == 'Italy') | (wine_reviews.birth_date == 18 Aug 2000)]
# Out:
#   File "<ipython-input-83-e6ed55387d17>", line 1
#     wine_reviews.loc[(wine_reviews.country == 'Italy') | (wine_reviews.birth_date == 18 Aug 2000)]
#                                                           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
wine_reviews.loc[wine_reviews.country.isin(['Ghana', 'Norwegia'])]
# Out:
#                                      first_name  last_name   birth_date  \
# participant_id
# ff1228c9-cbb8-4c85-abd3-2200ee871599    Natalia    Hartati  03 Oct 1992
# 1abb5ace-e2f8-4ac3-90d5-cdd70838ca50     Kusuma   Pradipta  04 Jan 1991
# 83d9dbf8-f13d-4171-989a-8995ec10468e    Cengkal     Habibi  12 Aug 1991
# 30ae7786-656c-4d62-afd5-f8050a3a7d93        Eli    Pratiwi  14 Aug 2001
# a9164451-a339-4adb-a8ba-6d0df31d00b0    Chelsea    Wastuti  18 Aug 1998
# ...                                         ...        ...          ...
# 62ef6e6d-faa6-4c05-9ddd-965868308542    Cengkir  Sihombing  27 Dec 1998
# dca95a5a-1ead-4350-9a79-12753e123246      Winda     Farida  22 May 1997
# 1b051939-bb6c-4546-bcef-e3dc5f6d58f5      Indra    Pratama  02 Sep 1991
# fc6e142a-3f66-4330-9975-8c1dc7f9bb03      Indah  Rahmawati  06 Mar 1996
# 4521ff9f-4aec-401b-84aa-a4e6fc6549a4      Irsad   Najmudin  14 Feb 2003
#
# ...

# %%
wine_reviews.loc[wine_reviews.phone_number.notnull()]
# Out:
#                                      first_name   last_name   birth_date  \
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a      Citra  Nurdiyanti  05 Feb 1991
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3       Aris    Setiawan  11 Jan 1993
# 19582d7f-b824-4fe5-a517-d5bf573fc768   Cornelia   Handayani  31 Jul 1993
# aeb6d817-25f3-4867-8a74-8d92e0a0f633      Soleh      Rajasa  04 Nov 1991
# 1fdabdd9-5444-4c97-87b2-fe8833ad0d27       Vivi      Astuti  22 Jan 2003
# ...                                         ...         ...          ...
# 5f084245-58cb-4360-8cff-112f06f7214e      Mitra    Latupono  27 Apr 2000
# fc6e142a-3f66-4330-9975-8c1dc7f9bb03      Indah   Rahmawati  06 Mar 1996
# 4521ff9f-4aec-401b-84aa-a4e6fc6549a4      Irsad    Najmudin  14 Feb 2003
# 1c91596e-427c-44a7-b7d0-974f44e18381      Carla    Nasyidah  22 Aug 1994
# 5d682e84-bcb5-43e9-8ce0-615364f5376a    Darmana     Maryadi  09 Feb 2002
#
# ...

# %%
#selecting

# %%
wine_reviews['critic'] = 'everyone'
wine_reviews['critic']
# Out:
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a    everyone
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3    everyone
# 19582d7f-b824-4fe5-a517-d5bf573fc768    everyone
# aeb6d817-25f3-4867-8a74-8d92e0a0f633    everyone
# 1fdabdd9-5444-4c97-87b2-fe8833ad0d27    everyone
#                                           ...
# 5f084245-58cb-4360-8cff-112f06f7214e    everyone
# fc6e142a-3f66-4330-9975-8c1dc7f9bb03    everyone
# 4521ff9f-4aec-401b-84aa-a4e6fc6549a4    everyone
# 1c91596e-427c-44a7-b7d0-974f44e18381    everyone
# 5d682e84-bcb5-43e9-8ce0-615364f5376a    everyone
# Name: critic, Length: 5000, dtype: object

# %%
wine_reviews['index_backwards'] = range(len(wine_reviews), 0, -1)
wine_reviews['index_backwards']
# Out:
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a    5000
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3    4999
# 19582d7f-b824-4fe5-a517-d5bf573fc768    4998
# aeb6d817-25f3-4867-8a74-8d92e0a0f633    4997
# 1fdabdd9-5444-4c97-87b2-fe8833ad0d27    4996
#                                         ...
# 5f084245-58cb-4360-8cff-112f06f7214e       5
# fc6e142a-3f66-4330-9975-8c1dc7f9bb03       4
# 4521ff9f-4aec-401b-84aa-a4e6fc6549a4       3
# 1c91596e-427c-44a7-b7d0-974f44e18381       2
# 5d682e84-bcb5-43e9-8ce0-615364f5376a       1
# Name: index_backwards, Length: 5000, dtype: int64

# %%
#

# %%
wine_reviews.country.describe()
# Out:
# count                  5000
# unique                  194
# top       Republik Irlandia
# freq                     43
# Name: country, dtype: object

# %%
wine_reviews.occupation.describe()
# Out:
# count                   5000
# unique                    14
# top       Fullstack Engineer
# freq                     397
# Name: occupation, dtype: object

# %%
wine_reviews.birth_date	.describe()
# Out:
# count            5000
# unique           3068
# top       31 Jul 1993
# freq                6
# Name: birth_date, dtype: object

# %%
wine_reviews.phone_number.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1691         try:
# -> 1692             x = float(x)
#    1693         except (TypeError, ValueError):
#
# ...

# %%
wine_reviews.first_name.unique()
# Out:
# array(['Citra', 'Aris', 'Cornelia', 'Soleh', 'Vivi', 'Bahuraksa', 'Tiara',
#        'Dimaz', 'Zizi', 'Cecep', 'Vanya', 'Yahya', 'Natalia', 'Karja',
#        'Maria', 'Kalim', 'Kezia', 'Saiful', 'Ani', 'Heru', 'Qori',
#        'Caraka', 'Anastasia', 'Kusuma', 'Rina', 'Cengkal', 'Wulan',
#        'Daryani', 'Jamalia', 'Rini', 'Hasan', 'Padma', 'Galih',
#        'Ghaliyati', 'Dasa', 'Ika', 'Galur', 'Salwa', 'Vino', 'Dalima',
#        'Harsaya', 'Lidya', 'Estiono', 'Novi', 'Taufik', 'Ulva', 'Irsad',
#        'Yessi', 'Luthfi', 'Ida', 'Nilam', 'Kemal', 'Eli', 'Edi',
#        'Belinda', 'Aditya', 'Nova', 'Tri', 'Sari', 'Jinawi', 'Wani',
#        'Jatmiko', 'Raina', 'Hendra', 'Vera', 'Wisnu', 'Adinata', 'Ifa',
#        'Bakijan', 'Caturangga', 'Hani', 'Eka', 'Kiandra', 'Waluyo',
#        'Kamila', 'Dalimin', 'Kayla', 'Daru', 'Catur', 'Halima', 'Hardana',
#        'Padmi', 'Legawa', 'Lintang', 'Cawisadi', 'Keisha', 'Tirtayasa',
# ...

# %%
wine_reviews.institute.value_counts()
# Out:
# institute
# Universitas Amir Hamzah                  28
# Universitas Proklamasi 45                23
# Universitas Airlangga                    23
# Universitas Khairun                      23
# Universitas Mulawarman                   22
#                                          ..
# Perum Maryadi Kusmawati (Persero) Tbk     1
# Perum Hassanah Astuti                     1
# Perum Susanti                             1
# Perum Anggriawan Andriani Tbk             1
# Perum Laksita Kuswandari                  1
# Name: count, Length: 2467, dtype: int64

# %%
#sum

# %%
wine_review_institute_mean = wine_reviews.institute.mean()
wine_reviews.institute.map(lambda p: p - review_institute_mean)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1691         try:
# -> 1692             x = float(x)
#    1693         except (TypeError, ValueError):
#
# ...

# %%
#do zroba

# %%
def remean_points(row):
    row.points = row.last_name - review_last_name_mean
    return row

wine_reviews.apply(remean_last_name, axis='columns')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-1e925a05e0a8> in <cell line: 5>()
#       3     return row
#       4
# ----> 5 wine_reviews.apply(remean_last_name, axis='columns')
#
# NameError: name 'remean_last_name' is not defined

# %%
wine_reviews.head(2)
# Out:
#                                      first_name   last_name   birth_date  \
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a      Citra  Nurdiyanti  05 Feb 1991
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3       Aris    Setiawan  11 Jan 1993
#
#                                                                              address  \
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a        Gg. Monginsidi No. 08\nMedan, Aceh 80734
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3  Gg. Rajawali Timur No. 7\nPrabumulih, MA 09434
#
#                                             phone_number      country  \
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a     (0151) 081 2706      Georgia
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3  +62 (036) 461 7027  Korea Utara
#
#                                                    institute  \
# participant_id
# bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a    UD Prakasa Mandasari
# 7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3  Universitas Diponegoro
#
# ...

# %%
wine_review_points_mean = reviews.points.mean()
wine_reviews.points - review_points_mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-cce33821319d> in <cell line: 1>()
# ----> 1 wine_review_points_mean = reviews.points.mean()
#       2 wine_reviews.points - review_points_mean
#
# NameError: name 'reviews' is not defined

# %%
wine_reviews.country + " - " + reviews.region_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-111-6e9adef18d7f> in <cell line: 1>()
# ----> 1 wine_reviews.country + " - " + reviews.region_1
#
# NameError: name 'reviews' is not defined
