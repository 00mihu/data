# %%
type(48)
# Out:
# int

# %%
type("hello KUB Datalab")
# Out:
# str

# %%
type(29.6)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
"THIS IS string"
# Out:
# 'THIS IS string'

# %%
"this is 'also' a string"
# Out:
# "this is 'also' a string"

# %%
#comment

# %%
"I am a string [7]"[7]
# Out:
# 's'

# %%
"I am a string" [0:7]
# Out:
# 'I am a '

# %%
"I am a string " + "and so am I"
# Out:
# 'I am a string and so am I'

# %%
4*2
# Out:
# 8

# %%
4**2
# Out:
# 16

# %%
72%10
# Out:
# 2

# %%
40/7
# Out:
# 5.714285714285714

# %%
13 < 17
# Out:
# True

# %%
13>17
# Out:
# False

# %%
print(5-3)
# Out:
# 2

# %%
print("hello" - "h")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-bf3795dd77ce> in <cell line: 1>()
# ----> 1 print("hello" - "h")
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
"string" + "string"
# Out:
# 'stringstring'

# %%
'some text' *10
# Out:
# 'some textsome textsome textsome textsome textsome textsome textsome textsome textsome text'

# %%
print(1+'2')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-e901f05e3348> in <cell line: 1>()
# ----> 1 print(1+'2')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(1 + int('2'))
# Out:
# 3

# %%
print("half is", 1/2.0)
# Out:
# half is 0.5

# %%
first = 1
second = 5* first
first = 2
print("first is", first, "")
# Out:
# first is 2

# %%
First_Name = mihu
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-18735e536c22> in <cell line: 1>()
# ----> 1 First_Name = mihu
#
# NameError: name 'mihu' is not defined

# %%
first_name = "Nynne"
age=18
print(first_name, "is", age)
# Out:
# Nynne is 18

# %%
age = age + 4
print("age in 4 years", age)
# Out:
# age in 4 years 22

# %%
print('hello class') #this is comment
# Out:
# hello class

# %%
print('hello class','elo elo')
# Out:
# hello class elo elo

# %%
print('something')
print()
print('trala')
# Out:
# something
#
# trala

# %%
#max and min
#0-9, a-z, A-Z
print(max(1,2,3))
print(max('a','b','e','r','g'))
# Out:
# 3
# r

# %%
help(max)
# Out:
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the largest argument.

# %%
a=34.5
round(a)
# Out:
# 34

# %%
andres = 636363.83838338
round(andres, 2)
# Out:
# 636363.84

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
result = print('example')
print('tralalalbum is' + result)
# Out:
# example
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-692213590bef> in <cell line: 2>()
#       1 result = print('example')
# ----> 2 print('tralalalbum is' + result)
#
# TypeError: can only concatenate str (not "NoneType") to str

# %%
#lists
my_first_list = []
temps = [16.5, 13.4, 17, 'feelin hot hot']
print(temps)
# Out:
# [16.5, 13.4, 17, 'feelin hot hot']

# %%
temps[0:3]
# Out:
# [16.5, 13.4, 17]

# %%
temps[3] = 15.6
print(temps)
# Out:
# [16.5, 13.4, 17, 15.6]

# %%
temps.append(17.9)
print(temps)
# Out:
# [16.5, 13.4, 17, 15.6, 17.9, 17.9, 17.9]

# %%
del temps[2]
print(temps)
# Out:
# [16.5, 13.4, 15.6, 17.9, 17.9, 17.9]

# %%
#ex
values = []
values.append(1)
values.append(3)
values.append(5)
print('first time:', values)
values = values[1:3]
print('second time:', values)
# Out:
# first time: [1, 3, 5]
# second time: [3, 5]

# %%
len(values) #lenght
# Out:
# 2

# %%
print('string to list:', list('tin'))
print('list to string:', ''.join(['g', 'o', 'l', 'd']))
print('list to string:', '-'.join(['g', 'o', 'l', 'd']))
# Out:
# string to list: ['t', 'i', 'n']
# list to string: gold
# list to string: g-o-l-d

# %%
element = 'helium'
print(element[-1])
print(element[0:-1])
# Out:
# m
# heliu

# %%
# Program A
letters = list('gold')
result = sorted(letters)
print('letters is', letters, 'and result is', result)
# Program B
letters = list('gold')
result = letters.sort()
print('letters is', letters, 'and result is', result)
# Out:
# letters is ['g', 'o', 'l', 'd'] and result is ['d', 'g', 'l', 'o']
# letters is ['d', 'g', 'l', 'o'] and result is None
