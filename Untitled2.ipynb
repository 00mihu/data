# %%
IDE:
uzywane: IDLE, Spyder, Notepad++, PyCharm, Jupyter

math % give rest f.ex. 6.4%2 = 0.4

# %%
6.4%2
# Out:
# 0.40000000000000036

# %%
f *= i
f *=i == f=f*i

# %%
i = 1
f = 1
while (i<100):
  f*=i
  i*=1
print(f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-d7a3abe3d243> in <cell line: 3>()
#       1 i = 1
#       2 f = 1
# ----> 3 while (i<100):
#       4   f*=i
#       5   i*=1
#
# KeyboardInterrupt:

# %%
ord("a")
ord("B")
# Out:
# 66

# %%
bool(-3)
bool(2)
# Out:
# True

# %%
def facultative(x):
  fac = 1
  while x>1:
    fac = fac * x
    x=x-1
  return fac
print(facultative(10))
# Out:
# 3628800

# %%
d = {"John"}

# %%
n=0
for i in range(17, 1000000, 17):
  if str(i) == str(i)[::-1]:
    n += 1
  print(i)
print(n)
