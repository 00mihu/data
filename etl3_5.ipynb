# %%
pip install pandas sqlalchemy

# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
#E

  #def extract(file_path):
  #   """Extract from CSV"""
db = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/dqthon-participants.csv")
  #return
db
# Out:
#                             participant_id first_name   last_name  \
# 0     bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a      Citra  Nurdiyanti
# 1     7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3       Aris    Setiawan
# 2     19582d7f-b824-4fe5-a517-d5bf573fc768   Cornelia   Handayani
# 3     aeb6d817-25f3-4867-8a74-8d92e0a0f633      Soleh      Rajasa
# 4     1fdabdd9-5444-4c97-87b2-fe8833ad0d27       Vivi      Astuti
# ...                                    ...        ...         ...
# 4995  5f084245-58cb-4360-8cff-112f06f7214e      Mitra    Latupono
# 4996  fc6e142a-3f66-4330-9975-8c1dc7f9bb03      Indah   Rahmawati
# 4997  4521ff9f-4aec-401b-84aa-a4e6fc6549a4      Irsad    Najmudin
# 4998  1c91596e-427c-44a7-b7d0-974f44e18381      Carla    Nasyidah
# 4999  5d682e84-bcb5-43e9-8ce0-615364f5376a    Darmana     Maryadi
#
#        birth_date                                            address  \
# 0     05 Feb 1991           Gg. Monginsidi No. 08\nMedan, Aceh 80734
# ...

# %%
#T

# %%
def transform(db):
    """Transform"""
    # Example transformation: filter rows where a specific column has a certain value
    db = db[db['Citra'] == 'Sitra']

    # Another example: rename columns
    db = db.rename(columns={'last_name': 'surname'})

    # Add more transformations as needed
    return db

# %%
db
# Out:
#                             participant_id first_name   last_name  \
# 0     bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a      Citra  Nurdiyanti
# 1     7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3       Aris    Setiawan
# 2     19582d7f-b824-4fe5-a517-d5bf573fc768   Cornelia   Handayani
# 3     aeb6d817-25f3-4867-8a74-8d92e0a0f633      Soleh      Rajasa
# 4     1fdabdd9-5444-4c97-87b2-fe8833ad0d27       Vivi      Astuti
# ...                                    ...        ...         ...
# 4995  5f084245-58cb-4360-8cff-112f06f7214e      Mitra    Latupono
# 4996  fc6e142a-3f66-4330-9975-8c1dc7f9bb03      Indah   Rahmawati
# 4997  4521ff9f-4aec-401b-84aa-a4e6fc6549a4      Irsad    Najmudin
# 4998  1c91596e-427c-44a7-b7d0-974f44e18381      Carla    Nasyidah
# 4999  5d682e84-bcb5-43e9-8ce0-615364f5376a    Darmana     Maryadi
#
#        birth_date                                            address  \
# 0     05 Feb 1991           Gg. Monginsidi No. 08\nMedan, Aceh 80734
# ...

# %%
#L

# %%
def load(db, database_url = "https://storage.googleapis.com/dqlab-dataset/dqthon-participants.csv", table_name = 'participants.csv'):
    """data into SQL db."""
    engine = create_engine(url="https://storage.googleapis.com/dqlab-dataset/dqthon-participants.csv")
    db.to_sql(table_name, engine, if_exists='replace', index=False)

# %%
# ETL Funkti

# %%
def etl(file_path, database_url, table_name):
    """ETL process: """
    # Extract
    df = extract(file_path)
    # Transform
    db = transform(db)
    # Load
    load(db, database_url, table_name)

# %%
#exmpl

# %%
if __name__ == "__main__":
    file_path = 'path/to/your/source_file.csv'
    database_url = 'sqlite:///your_database.db'  # Example for SQLite; adjust for other DBMS
    table_name = 'your_table_name'

    etl(file_path, database_url, table_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-70451da7c92c> in <cell line: 1>()
#       4     table_name = 'your_table_name'
#       5
# ----> 6     etl(file_path, database_uri, table_name)
#
# <ipython-input-48-ebfa06af31ab> in etl(file_path, database_url, table_name)
#       2     """ETL process: """
#       3     # Extract
# ----> 4     df = extract(file_path)
#       5     # Transform
#       6     db = transform(db)
#
# <ipython-input-3-8997058bc4dc> in extract(file_path)
#       4 def extract(file_path):
#       5     """Extract data from a CSV file."""
# ----> 6     df = pd.read_csv(file_path)
#       7     return df
#       8
#
# ...

# %%
copyright etl = GePeTo 3,5
